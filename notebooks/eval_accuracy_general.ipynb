# %% [markdown]
# ## Evalulation of Accuracy With Logprob

# %% [markdown]
# ### Task1

# %%
import pandas as pd
import numpy as np
import glob
import os
import pandas as pd

base_dir = "data/extraction_pdf/datasets/output_gammar_results"
all_jsonl = glob.glob(os.path.join(base_dir, "**", "*.jsonl"), recursive=True) 
task_files = [p for p in all_jsonl if "task1" in os.path.basename(p) or "task1" in p]  

df_summary = pd.DataFrame()
for f in task_files:
    print("Calculating for file:", f)
    # if "20251004_210838" not in f:
    #     continue
    df = pd.read_json(f, lines=True)
    num_correct = 0
    total = len(df)
    df_final = pd.DataFrame()
    for idx, row in df.iterrows():

        key = f.split("/")[-1].split("_")[0]+"_dict"
        if key =="task4_dict":
            key = "output_dict_mp"
        if pd.isnull(row[key]):
            print(f"Warning: Missing {key} in row {idx}.")
            continue

        # print(f"Processing row {idx}")
        log_prob_dict = row["log_probs"]["content"]
        correct_grammar_letter = row["correct_grammar_letter"]

        ## Calculate NLL with Log Probabilities
        for item in log_prob_dict:
            # print(f"Decoded token: {item['token']}, Number: {item['bytes']}")
            if item['token'] == correct_grammar_letter:
                logprob_list = item["top_logprobs"]
                for log_prob_dict in logprob_list:
                    if correct_grammar_letter == log_prob_dict["token"]:
                        log_probs = log_prob_dict["logprob"]
                        nll = -log_probs
                        probs_from_logprobs = np.exp(log_probs)
                        # print(f"Log probabilities for token '{correct_grammar_letter}': {log_probs}")
                        # print(f"Probabilities for token '{correct_grammar_letter}': {probs_from_logprobs}")
                        row["log_probs_value"] = log_probs
                        row["nll"] = nll
                        row["probs_from_logprobs"] = probs_from_logprobs
                        # print(f"Probabilities for token '{correct_grammar_letter}': {probs_from_logprobs}")
                        if np.isnan(nll):
                            print(f"NaN found in NLL for row {idx}")
                        break

        ## Calculate Accuracy
        correct_grammar_letter = row['correct_grammar_letter']
        detected_grammar_letter = str(row['task1_dict'].get('grammar_selected') or "").strip().upper()
        
        
        if correct_grammar_letter == detected_grammar_letter:
            num_correct += 1
            row['is_correct'] = True
        
        else:
            row['is_correct'] = False
        
        row_df = pd.DataFrame([row])
        df_final = pd.concat([df_final, row_df], ignore_index=True)

    acc = num_correct / len(df_final)
    std = np.sqrt(acc * (1 - acc) /  len(df_final))
    probs_list = df_final["probs_from_logprobs"].dropna().values
    probs_mean = np.mean(probs_list)
    probs_std = np.std(probs_list)

    print(f"Accuracy: {num_correct}/{ len(df_final)} = {acc:.2f} ± {std:.2f}")
    print(f"Probabilities: {probs_mean:.2f} ± {probs_std:.2f}")

    str_accuracy = f"{acc:.2f}_±_{std:.2f}"
    str_probs = f"{probs_mean:.2f}_±_{probs_std:.2f}"
    row = {
        "file_name": os.path.basename(f),
        "str_accuracy": str_accuracy,
        "str_probs": str_probs,
        "accuracy": acc,
        "accuracy_std": std,
        "probs_mean": probs_mean,
        "probs_std": probs_std 

    }
    row_df = pd.DataFrame([row])
    df_summary = pd.concat([df_summary, row_df], ignore_index=True)

df_summary.to_json("data/extraction_pdf/datasets/SUMMARY/results_summary_task1.json", orient="records", lines=True)
# Out:
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251005_000046_10_gemma-2-9b-it.jsonl
# Accuracy: 1068/2040 = 0.52 ± 0.01
# Probabilities: 0.95 ± 0.14
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_233446_9_gemma-2-9b-it.jsonl
# Accuracy: 1045/2040 = 0.51 ± 0.01
# Probabilities: 0.95 ± 0.14
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_222713_6_gemma-2-9b-it.jsonl
# Accuracy: 1167/2040 = 0.57 ± 0.01
# Probabilities: 0.96 ± 0.15
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_212657_3_gemma-2-9b-it.jsonl
# Accuracy: 1743/2040 = 0.85 ± 0.01
# Probabilities: 0.98 ± 0.08
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_220625_5_gemma-2-9b-it.jsonl
# Accuracy: 1207/2040 = 0.59 ± 0.01
# Probabilities: 0.96 ± 0.13
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_231104_8_gemma-2-9b-it.jsonl
# Accuracy: 1024/2040 = 0.50 ± 0.01
# Probabilities: 0.94 ± 0.16
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_224845_7_gemma-2-9b-it.jsonl
# Accuracy: 1046/2040 = 0.51 ± 0.01
# Probabilities: 0.95 ± 0.14
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_214616_4_gemma-2-9b-it.jsonl
# Accuracy: 1234/2040 = 0.60 ± 0.01
# Probabilities: 0.97 ± 0.12
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_210838_2_gemma-2-9b-it.jsonl
# Accuracy: 1695/2040 = 0.83 ± 0.01
# Probabilities: 0.98 ± 0.08
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task1_20251003_213357_10_gemma-2-2b-it.jsonl
# Accuracy: 659/2040 = 0.32 ± 0.01
# Probabilities: 0.81 ± 0.27
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task1_20251003_205537_6_gemma-2-2b-it.jsonl
# Accuracy: 949/2040 = 0.47 ± 0.01
# Probabilities: 0.89 ± 0.22
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task1_20251003_210434_7_gemma-2-2b-it.jsonl
# Accuracy: 778/2040 = 0.38 ± 0.01
# Probabilities: 0.89 ± 0.22
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task1_20251003_203834_4_gemma-2-2b-it.jsonl
# Accuracy: 1206/2040 = 0.59 ± 0.01
# Probabilities: 0.92 ± 0.19
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task1_20251003_202254_2_gemma-2-2b-it.jsonl
# Accuracy: 1638/2040 = 0.80 ± 0.01
# Probabilities: 0.98 ± 0.09
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task1_20251003_204656_5_gemma-2-2b-it.jsonl
# Accuracy: 1152/2040 = 0.56 ± 0.01
# Probabilities: 0.91 ± 0.18
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task1_20251003_203037_3_gemma-2-2b-it.jsonl
# Accuracy: 1567/2040 = 0.77 ± 0.01
# Probabilities: 0.96 ± 0.13
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task1_20251003_212346_9_gemma-2-2b-it.jsonl
# Accuracy: 726/2040 = 0.36 ± 0.01
# Probabilities: 0.82 ± 0.27
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task1_20251003_211405_8_gemma-2-2b-it.jsonl
# Accuracy: 733/2040 = 0.36 ± 0.01
# Probabilities: 0.85 ± 0.25

# %%
import pandas as pd
import numpy as np
import glob
import os
import pandas as pd

base_dir = "data/extraction_pdf/datasets/output_gammar_results"
all_jsonl = glob.glob(os.path.join(base_dir, "**", "*.jsonl"), recursive=True) 
task_files = [p for p in all_jsonl if "task2" in os.path.basename(p) or "task2" in p]  

df_summary = pd.DataFrame()
for f in task_files:
    print("Calculating for file:", f)
    df = pd.read_json(f, lines=True)
    num_correct = 0
    total = len(df)
    df_final = pd.DataFrame()
    for idx, row in df.iterrows():
        # print(f"Processing row {idx}")
        key = f.split("/")[-1].split("_")[0]+"_dict"
        if key =="task4_dict":
            key = "output_dict_mp"
        if pd.isnull(row[key]):
            print(f"Warning: Missing {key} in row {idx}.")
            continue
        log_prob_dict = row["log_probs"]["content"]
        correct_grammar_letter = row["correct_sentence_letter"]

        ## Calculate NLL with Log Probabilities
        for item in log_prob_dict:
            # print(f"Decoded token: {item['token']}, Number: {item['bytes']}")
            if item['token'] == correct_grammar_letter:
                logprob_list = item["top_logprobs"]
                for log_prob_dict in logprob_list:
                    if correct_grammar_letter == log_prob_dict["token"]:
                        log_probs = log_prob_dict["logprob"]
                        nll = -log_probs
                        probs_from_logprobs = np.exp(log_probs)
                        # print(f"Log probabilities for token '{correct_grammar_letter}': {log_probs}")
                        # print(f"Probabilities for token '{correct_grammar_letter}': {probs_from_logprobs}")
                        row["log_probs_value"] = log_probs
                        row["nll"] = nll
                        row["probs_from_logprobs"] = probs_from_logprobs
                        if np.isnan(nll):
                            print(f"NaN found in NLL for row {idx}")
                        break

        ## Calculate Accuracy
        correct_grammar_letter = row['correct_sentence_letter']
        detected_grammar_letter = str(row['task2_dict'].get('sentence_selected') or "").strip().upper()
        if correct_grammar_letter == detected_grammar_letter:
            num_correct += 1
            row['is_correct'] = True
        
        else:
            row['is_correct'] = False
        
        row_df = pd.DataFrame([row])
        df_final = pd.concat([df_final, row_df], ignore_index=True)

    acc = num_correct / len(df_final)
    std = np.sqrt(acc * (1 - acc) /  len(df_final))
    probs_list = df_final["probs_from_logprobs"].dropna().values
    probs_mean = np.mean(probs_list)
    probs_std = np.std(probs_list)

    print(f"Accuracy: {num_correct}/{len(df_final)} = {acc:.2f} ± {std:.2f}")
    print(f"Probabilities: {probs_mean:.2f} ± {probs_std:.2f}")
    str_accuracy = f"{acc:.2f}_±_{std:.2f}"
    str_probs = f"{probs_mean:.2f}_±_{probs_std:.2f}"

    row = {
        "file_name": os.path.basename(f),
        "str_accuracy": str_accuracy,
        "str_probs": str_probs,
        "accuracy": acc,
        "accuracy_std": std,
        "probs_mean": probs_mean,
        "probs_std": probs_std 

    }
    row_df = pd.DataFrame([row])
    df_summary = pd.concat([df_summary, row_df], ignore_index=True)
df_summary.to_json("data/extraction_pdf/datasets/SUMMARY/results_summary_task2.json", orient="records", lines=True)
# Out:
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_004943_6_gemma-2-9b-it.jsonl
# Accuracy: 561/673 = 0.83 ± 0.01
# Probabilities: 0.97 ± 0.11
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_004320_5_gemma-2-9b-it.jsonl
# Accuracy: 568/673 = 0.84 ± 0.01
# Probabilities: 0.98 ± 0.11
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_003117_3_gemma-2-9b-it.jsonl
# Accuracy: 603/673 = 0.90 ± 0.01
# Probabilities: 0.98 ± 0.08
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_010259_8_gemma-2-9b-it.jsonl
# Accuracy: 532/673 = 0.79 ± 0.02
# Probabilities: 0.98 ± 0.08
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_003714_4_gemma-2-9b-it.jsonl
# Accuracy: 571/673 = 0.85 ± 0.01
# Probabilities: 0.98 ± 0.09
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_002534_2_gemma-2-9b-it.jsonl
# Accuracy: 621/673 = 0.92 ± 0.01
# Probabilities: 0.98 ± 0.07
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_005616_7_gemma-2-9b-it.jsonl
# Accuracy: 534/673 = 0.79 ± 0.02
# Probabilities: 0.97 ± 0.12
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_010949_9_gemma-2-9b-it.jsonl
# Accuracy: 525/673 = 0.78 ± 0.02
# Probabilities: 0.97 ± 0.11
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_011646_10_gemma-2-9b-it.jsonl
# Accuracy: 534/673 = 0.79 ± 0.02
# Probabilities: 0.96 ± 0.14
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task2_20251003_214646_3_gemma-2-2b-it.jsonl
# Accuracy: 911/1124 = 0.81 ± 0.01
# Probabilities: 0.96 ± 0.12
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task2_20251003_215505_6_gemma-2-2b-it.jsonl
# Accuracy: 776/1124 = 0.69 ± 0.01
# Probabilities: 0.94 ± 0.15
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task2_20251003_215758_7_gemma-2-2b-it.jsonl
# Accuracy: 749/1124 = 0.67 ± 0.01
# Probabilities: 0.94 ± 0.15
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task2_20251003_214417_2_gemma-2-2b-it.jsonl
# Accuracy: 1082/1249 = 0.87 ± 0.01
# Probabilities: 0.97 ± 0.10
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task2_20251003_215205_5_gemma-2-2b-it.jsonl
# Accuracy: 803/1124 = 0.71 ± 0.01
# Probabilities: 0.94 ± 0.15
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task2_20251003_220055_8_gemma-2-2b-it.jsonl
# Accuracy: 728/1124 = 0.65 ± 0.01
# Probabilities: 0.91 ± 0.19
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task2_20251003_220701_10_gemma-2-2b-it.jsonl
# Accuracy: 662/1124 = 0.59 ± 0.01
# Probabilities: 0.89 ± 0.21
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task2_20251003_220356_9_gemma-2-2b-it.jsonl
# Accuracy: 694/1124 = 0.62 ± 0.01
# Probabilities: 0.91 ± 0.19
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task2_20251003_214916_4_gemma-2-2b-it.jsonl
# Accuracy: 823/1124 = 0.73 ± 0.01
# Probabilities: 0.95 ± 0.14

# %%
import pandas as pd
import numpy as np
import glob
import os
import pandas as pd

base_dir = "data/extraction_pdf/datasets/output_gammar_results"
all_jsonl = glob.glob(os.path.join(base_dir, "**", "*.jsonl"), recursive=True) 
task_files = [p for p in all_jsonl if "task3" in os.path.basename(p) or "task3" in p]  

df_summary = pd.DataFrame()
for f in task_files:
    print("Calculating for file:", f)
    df = pd.read_json(f, lines=True)

    total_score = 0 
    total = len(df)
    df_final = pd.DataFrame()
    for idx, row in df.iterrows():

        # print(f"Processing row {idx}")
        key = f.split("/")[-1].split("_")[0]+"_dict"
        if key =="task4_dict":
            key = "output_dict_mp"
        if pd.isnull(row[key]):
            print(f"Warning: Missing {key} in row {idx}.")
            continue

        # print(f"Processing row {idx}")
        log_prob_dict = row["log_probs"]["content"]
        correct_grammar_letters = row["correct_grammars_letter"]

        ## Calculate NLL with Log Probabilities
        prob_accu = 0.0

        for correct_grammar_letter in correct_grammar_letters:
            # Find all log prob outputs
            for item in log_prob_dict:
                if item['token'] == str(correct_grammar_letter):
                    logprob_list = item["top_logprobs"]
                    # Find the log prob for the correct grammar letter
                    for log_prob in logprob_list:
                        if str(correct_grammar_letter) == log_prob["token"]:
                            log_probs = log_prob["logprob"]
                            nll = -log_probs
                            probs_from_logprobs = np.exp(log_probs)
                            # print(f"Log probabilities for token '{correct_grammar_letter}': {log_probs}")
                            # print(f"Probabilities for token '{correct_grammar_letter}': {probs_from_logprobs}")

                            prob_accu += probs_from_logprobs
                            if np.isnan(nll):
                                print(f"NaN found in NLL for row {idx}")
                            break
                    break
        row["prob_accu"] = prob_accu/len(correct_grammar_letters) if correct_grammar_letters else 2
        ## Calculate Accuracy
        correct_set = set(row['correct_grammars_letter'])
        try:
            detected_set = str(row['task3_dict'].get('grammar_selected') or "").strip().upper()
        except TypeError as e:
            if "unhashable type: 'dict'" in str(e):
                detected_grammar_letter = None 
                continue
            else:
                raise  
        
        score = len(detected_set & correct_set) / len(correct_set)
        total_score += score

        row["total_score"] = score
        row_df = pd.DataFrame([row])
        df_final = pd.concat([df_final, row_df], ignore_index=True)

    acc = total_score / len(df_final)
    std = np.sqrt(acc * (1 - acc) / len(df_final))

    probs_list = df_final["prob_accu"].dropna().values
    probs_mean = np.mean(probs_list)
    probs_std = np.std(probs_list)

    print(f"Accuracy: {total_score}/{len(df_final)} = {acc:.2f} ± {std:.2f}")
    print(f"Probabilities: {probs_mean:.2f} ± {probs_std:.2f}")
    str_accuracy = f"{acc:.2f}_±_{std:.2f}"
    str_probs = f"{probs_mean:.2f}_±_{probs_std:.2f}"

    row = {
        "file_name": os.path.basename(f),
        "str_accuracy": str_accuracy,
        "str_probs": str_probs,
        "accuracy": acc,
        "accuracy_std": std,
        "probs_mean": probs_mean,
        "probs_std": probs_std 

    }
    row_df = pd.DataFrame([row])
    df_summary = pd.concat([df_summary, row_df], ignore_index=True)

df_summary.to_json("data/extraction_pdf/datasets/SUMMARY/results_summary_task3.json", orient="records", lines=True)
# Out:
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_021619_10_2_1000_gemma-2-9b-it.jsonl
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x702bc4610c40>>
# Traceback (most recent call last):
#   File "/home/snt/projects_lujun/mt_reasoning/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 781, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import glob
import os
import pandas as pd

base_dir = "data/extraction_pdf/datasets/output_gammar_results"
all_jsonl = glob.glob(os.path.join(base_dir, "**", "*.jsonl"), recursive=True) 
task_files = [p for p in all_jsonl if "task4" in os.path.basename(p) or "task4" in p]  
log_prob_name = "log_prob_mp"  # log_prob_mp_single_1  log_prob_mp_single_2 log_prob_mp_with_grammar_desc
output_dict_name = "output_dict_mp"  # output_dict_mp_single_1  output_dict_mp_single_2 output_dict_mp_with_grammar_desc
df_summary = pd.DataFrame()
for f in task_files:
    print("Calculating for file:", f)
    df = pd.read_json(f, lines=True)
    total_score = 0 
    num_correct = 0
    total = len(df)
    df_final = pd.DataFrame()
    for idx, row in df.iterrows():

        # print(f"Processing row {idx}")
        key = f.split("/")[-1].split("_")[0]+"_dict"
        if key =="task4_dict":
            key = "output_dict_mp"
        if pd.isnull(row[key]):
            print(f"Warning: Missing {key} in row {idx}.")
            continue

        # print(f"Processing row {idx}")
        log_prob_dict = row[log_prob_name]["content"]
        correct_sentence_letter = row["correct_sentence_letter"]

        ## Calculate NLL with Log Probabilities
        for item in log_prob_dict:
            # print(f"Decoded token: {item['token']}, Number: {item['bytes']}")
            if item['token'] == correct_sentence_letter:
                logprob_list = item["top_logprobs"]
                for log_prob_dict in logprob_list:
                    if correct_sentence_letter == log_prob_dict["token"]:
                        log_probs = log_prob_dict["logprob"]
                        nll = -log_probs
                        probs_from_logprobs = np.exp(log_probs)
                        row["log_probs_value"] = log_probs
                        row["nll"] = nll
                        row["probs_from_logprobs"] = probs_from_logprobs
                        # print(f"Probabilities for token '{correct_grammar_letter}': {probs_from_logprobs}")
                        if np.isnan(nll):
                            print(f"NaN found in NLL for row {idx}")
                        break

        ## Calculate Accuracy
        correct_sentence_letter = row['correct_sentence_letter']
        detected_sentence_letter = row[output_dict_name].get('sentence_selected', '').strip().upper()
        if correct_sentence_letter == detected_sentence_letter:
            num_correct += 1
            row['is_correct'] = True
        
        else:
            row['is_correct'] = False
        
        row_df = pd.DataFrame([row])
        df_final = pd.concat([df_final, row_df], ignore_index=True)

    acc = num_correct / len(df_final)
    std = np.sqrt(acc * (1 - acc) / len(df_final))
    probs_list = df_final["probs_from_logprobs"].dropna().values
    probs_mean = np.mean(probs_list)
    probs_std = np.std(probs_list)

    print(f"Accuracy: {num_correct}/{len(df_final)} = {acc:.2f} ± {std:.2f}")
    print(f"Probabilities: {probs_mean:.2f} ± {probs_std:.2f}")


    str_accuracy = f"{acc:.2f}_±_{std:.2f}"
    str_probs = f"{probs_mean:.2f}_±_{probs_std:.2f}"
    row = {
        "file_name": os.path.basename(f),
        "str_accuracy": str_accuracy,
        "str_probs": str_probs,
        "accuracy": acc,
        "accuracy_std": std,
        "probs_mean": probs_mean,
        "probs_std": probs_std 

    }
    row_df = pd.DataFrame([row])
    df_summary = pd.concat([df_summary, row_df], ignore_index=True)

df_summary.to_json("data/extraction_pdf/datasets/SUMMARY/results_summary_task4.json", orient="records", lines=True)
# Out:
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task4_20251005_044742_gemma-2-9b-it.jsonl
# Accuracy: 1039/2040 = 0.51 ± 0.01
# Probabilities: 0.93 ± 0.18
# Calculating for file: data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/task4_20251003_230112_gemma-2-2b-it.jsonl
# Accuracy: 1012/2040 = 0.50 ± 0.01
# Probabilities: 0.84 ± 0.23

# %%
import pandas as pd
import glob

for f in glob.glob("data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/*.jsonl"):
    df = pd.read_json(f, lines=True)
    key = f.split("/")[-1].split("_")[0]+"_dict"
    if key =="task4_dict":
        key = "output_dict_mp"
    if "df" in key or "back" in key:
        continue
    print (f"{f}: {len(df[df[key].isnull()])}")
# Out:
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251005_000046_10_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_021619_10_2_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_004943_6_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_233446_9_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_222713_6_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_212657_3_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_220625_5_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_004320_5_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_231104_8_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_003117_3_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_224845_7_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_214616_4_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_010259_8_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_035629_15_3_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_031315_9_3_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_003714_4_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_015859_8_2_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_023424_12_2_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_012352_4_2_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task4_20251005_044742_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_042205_18_3_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_025420_6_3_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_002534_2_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task1_20251004_210838_2_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_005616_7_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_014059_6_2_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_010949_9_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task3_20251005_033353_12_3_1000_gemma-2-9b-it.jsonl: 0
# data/extraction_pdf/datasets/output_gammar_results/gemma-2-9b-it/task2_20251005_011646_10_gemma-2-9b-it.jsonl: 0

# %%
import pandas as pd
import glob

for f in glob.glob("data/extraction_pdf/datasets/output_gammar_results/gemma-2-2b-it/*.jsonl"):
    df = pd.read_json(f, lines=True)
    key = f.split("/")[-1].split("_")[0]+"_dict"
    if key =="task4_dict":
        key = "output_dict_mp"
    if "df" in key or "back" in key:
        continue
    print (f"{f}: {len(df[df[key].isnull()])}")

# %% [markdown]
# ## Eval Translation Service

# %%
import pandas as pd

df = pd.read_json("data/performance_eval/task_eval_translation_20251006_213226_gemma-2-9b-it.jsonl", lines=True)

subset = df[~df["task_translation_dict"].isnull()][
    ["CometScore", "CometScoreSmall", "spbleu_score", "chrf_score"]
]

# 计算 mean 和 std
means = subset.mean()
stds = subset.std()
for col in subset.columns:
    result = f"{means[col]:.2f} ± {stds[col]:.2f}"
    print(f"{col}: {result}")
# Out:
# CometScore: 0.18 ± 0.13
# CometScoreSmall: 0.33 ± 0.09
# spbleu_score: 11.28 ± 8.48
# chrf_score: 31.87 ± 8.81
